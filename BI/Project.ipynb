# %%
import numpy as np
import pandas as pd

df = pd.read_csv("insurance_claims-Subset.csv")

# %%
df
# Out:
#      months_as_customer  age  policy_number policy_state policy_csl  \
# 0                   328   48         521585           OH    250/500
# 1                   228   42         342868           IN    250/500
# 2                   134   29         687698           OH    100/300
# 3                   256   41         227811           IL    250/500
# 4                   228   44         367455           IL   500/1000
# ..                  ...  ...            ...          ...        ...
# 995                   3   38         941851           OH   500/1000
# 996                 285   41         186934           IL    100/300
# 997                 130   34         918516           OH    250/500
# 998                 458   62         533940           IL   500/1000
# 999                 456   60         556080           OH    250/500
#
#      policy_deductable  policy_annual_premium  umbrella_limit insured_sex  \
# 0                 1000                1406.91               0        MALE
# ...

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_state',
#        'policy_csl', 'policy_deductable', 'policy_annual_premium',
#        'umbrella_limit', 'insured_sex', 'insured_education_level',
#        'insured_occupation', 'insured_hobbies', 'insured_relationship',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'incident_state', 'incident_city', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'police_report_available', 'total_claim_amount', 'injury_claim',
#        'property_claim', 'vehicle_claim', 'auto_make', 'auto_model',
#        'auto_year', 'fraud_reported'],
#       dtype='object')

# %%
df.injury_claim.sum(), df.property_claim.sum(), df.vehicle_claim.sum(),df.total_claim_amount.sum()
# Out:
# (7433420, 7399570, 37928950, 52761940)

# %%
df.property_damage.value_counts()
# Out:
# ?      360
# NO     338
# YES    302
# Name: property_damage, dtype: int64

# %%
df.incident_hour_of_the_day.value_counts()
# Out:
# 17    54
# 3     53
# 0     52
# 23    51
# 16    49
# 13    46
# 10    46
# 4     46
# 6     44
# 9     43
# 14    43
# 21    42
# 18    41
# 12    40
# 19    40
# 7     40
# 15    39
# 22    38
# 8     36
# 20    34
# 5     33
# 2     31
# 11    30
# 1     29
# Name: incident_hour_of_the_day, dtype: int64

# %%
df.total_claim_amount.sum()
# Out:
# 52761940

# %%
df.shape
# Out:
# (1000, 32)
